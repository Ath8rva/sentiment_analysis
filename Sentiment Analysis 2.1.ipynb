# %%
api_key = 'AIzaSyDUjO3b9RAmQQKtrW6STXXrjRheNmMsFIE'

# %%
import googleapiclient.discovery
import google_auth_oauthlib.flow

# %%
api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = api_key

youtube = googleapiclient.discovery.build(api_service_name, api_version, developerKey = DEVELOPER_KEY)

# %%
#Get Comments on Video
request = youtube.comments().list(
    part="snippet",
    parentId="UgzDE2tasfmrYLyNkGt4AaABAg"
)
response = request.execute()

print(response)
# Out:
# {'kind': 'youtube#commentListResponse', 'etag': 'siy59D-iAsFI0hv4wPED_nziMyU', 'pageInfo': {'resultsPerPage': 20}, 'items': [{'kind': 'youtube#comment', 'etag': 'SrOsyGCywzWnnc1lDNMXBUcaymg', 'id': 'UgzDE2tasfmrYLyNkGt4AaABAg.8g7oZbuBjXg9RT71EGKJVm', 'snippet': {'textDisplay': 'Test', 'textOriginal': 'Test', 'parentId': 'UgzDE2tasfmrYLyNkGt4AaABAg', 'authorDisplayName': 'mg Gelloiss', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLS4jCsWGSCVdphxd9i2C0GH3xC8U6s7TKeX6yU_=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCxiu9DiB5Zdx3WodU2ZYV3Q', 'authorChannelId': {'value': 'UCxiu9DiB5Zdx3WodU2ZYV3Q'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2021-08-25T10:24:54Z', 'updatedAt': '2021-08-25T10:24:54Z'}}, {'kind': 'youtube#comment', 'etag': 'ZPiEFiwgeZOBqpajtvCrKHIxx4I', 'id': 'UgzDE2tasfmrYLyNkGt4AaABAg.8g7oZbuBjXg9RIvP-S8otK', 'snippet': {'textDisplay': 'Test', 'textOriginal': 'Test', 'parentId': 'UgzDE2tasfmrYLy
# ...

# %%
#Get Channel Details
request = youtube.channels().list(part = 'statistics', forUsername = 'TheEllenShow')

response = request.execute()

for i in response:
    if i == 'items':
        for j in response[i][0]:
            print(j, '=', response[i][0][j])
    else:
        print(i, '=', response[i])
# Out:
# kind = youtube#channelListResponse
# etag = 8p3Y0gOeF6HgRs-7Y7qkv_OytMs
# pageInfo = {'totalResults': 1, 'resultsPerPage': 5}
# kind = youtube#channel
# etag = x0OVLxXkBRepYWr6dtTsGubjwyQ
# id = UCp0hYYBW6IMayGgR-WeoCvQ
# statistics = {'viewCount': '21595021996', 'subscriberCount': '38000000', 'hiddenSubscriberCount': False, 'videoCount': '13341'}

# %%
#Get Videos Details
request = youtube.videos().list(part = 'statistics', id = '5fcHpUsX4Ig')

response = request.execute()

print(response)
# Out:
# {'kind': 'youtube#videoListResponse', 'etag': 'pPjBmTLe7uc8GZEyF8BpHwglpkw', 'items': [{'kind': 'youtube#video', 'etag': 'kKdGnKqQbQTzeqKHvXsOpx8TgQ0', 'id': '5fcHpUsX4Ig', 'statistics': {'viewCount': '37376', 'likeCount': '522', 'dislikeCount': '128', 'favoriteCount': '0', 'commentCount': '70'}}], 'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
#Search Using Keyword
request = youtube.search().list(part = 'snippet', q = 'TheEllenShow')

response = request.execute()

print(response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-00317d17db51> in <module>
#       3
#       4 response = request.execute()
# ----> 5 new = request.next()
#       6
#       7 print(response)
#
# AttributeError: 'HttpRequest' object has no attribute 'next'
